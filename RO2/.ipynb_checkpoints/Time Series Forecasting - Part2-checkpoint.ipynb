# %% [markdown]
# # Time Series Forecasting with XGBoost - Use python and machine learning to predict energy consumption
#
# #### https://www.youtube.com/watch?v=vV12dGe_Fho
# #### https://www.youtube.com/watch?v=z3ZnOW-S550

# %%
# Load the library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Dataset link
# - [hourly-energy-consumption](https://www.kaggle.com/datasets/robikscube/hourly-energy-consumption)

# %%
df = pd.read_csv('Hourly_Energy_Consumption_Dataset/PJME_hourly.csv')### Dataset description
df = df.set_index('Datetime')
df.index = pd.to_datetime(df.index)

# %%
df.head()
# Out:
#                      PJME_MW
# Datetime
# 2002-12-31 01:00:00  26498.0
# 2002-12-31 02:00:00  25147.0
# 2002-12-31 03:00:00  24574.0
# 2002-12-31 04:00:00  24393.0
# 2002-12-31 05:00:00  24860.0

# %%
df.shape
# Out:
# (145366, 1)

# %%
df.plot(style='.',
        figsize=(15, 5),
        color=color_pal[0],
        title='PJME Energy Use in MW')
plt.show()

# %% [markdown]
# ### Outline
# - Outlier analysis
# - Forecasting horizon explained
# - Time series cross validation
# - Lag features
# - Predicting the future

# %% [markdown]
# ### Outlier Analysis and removal

# %%
df['PJME_MW'].plot(kind='hist', bins=500)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.query('PJME_MW < 20_000')['PJME_MW'].plot(style='.', 
                                             figsize=(15, 5), 
                                             title='Outliers')
# Out:
# <AxesSubplot:title={'center':'Outliers'}, xlabel='Datetime'>

# %%
df.query('PJME_MW < 19_000')['PJME_MW'].plot(style='.', 
                                             figsize=(15, 5),
                                             color=color_pal[5],
                                             title='Outliers')
# Out:
# <AxesSubplot:title={'center':'Outliers'}, xlabel='Datetime'>

# %%
df = df.query('PJME_MW > 19_000').copy()

# %% [markdown]
# ### Train / Test Split

# %%
train = df.loc[df.index < '01-01-2015']
test = df.loc[df.index >= '01-01-2015']

fig, ax = plt.subplots(figsize=(15, 5))
train.plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test.plot(ax=ax, label='Test Set')
ax.axvline('01-01-2015', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %%
# How the one single week data looks like:
df.loc[(df.index > '01-01-2010') & (df.index < '01-08-2010')] \
    .plot(figsize=(15, 5), title='Week Of Data')
plt.show()

# %% [markdown]
# ### Time Series Cross Validationgrid=True,

# %%
from sklearn.model_selection import TimeSeriesSplit
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html
# test_size=24*365*1 : 24 hrs. * 365 days * 1 year
# gap=24 : gap between training and testing dataset (24 hrs.)

tss = TimeSeriesSplit(n_splits=5, test_size=24*365*1, gap=24)
df = df.sort_index()

# %%
fig, axs = plt.subplots(5, 1, figsize=(15, 15), sharex=True)

fold = 0
for train_idx, val_idx in tss.split(df):
    train = df.iloc[train_idx]
    test = df.iloc[val_idx]
    train['PJME_MW'].plot(ax=axs[fold],
                          label='Training Set',
                          title=f'Data Train/Test Split Fold {fold}')
    test['PJME_MW'].plot(ax=axs[fold],
                         label='Test Set')
    axs[fold].axvline(test.index.min(), color='black', ls='--')
    fold += 1
plt.show()

# %% [markdown]
# ### Forecasting Horizon Explained
# The forecast horizon is `the length of time into the future for which forecasts are to be prepared`. These generally vary from short-term forecasting horizons (less than three months) to long-term horizons (more than two years).

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

df = create_features(df)

# %% [markdown]
# ### Lag Features
# What was `the target (x) days in the past`.

# %%
def add_lags(df):
    target_map = df['PJME_MW'].to_dict()
    df['lag1'] = (df.index - pd.Timedelta('364 days')).map(target_map)
    df['lag2'] = (df.index - pd.Timedelta('728 days')).map(target_map)
    df['lag3'] = (df.index - pd.Timedelta('1092 days')).map(target_map)
    return df

df = add_lags(df)

# %%
df.tail()
# Out:
#                      PJME_MW  hour  dayofweek  quarter  month  year  \
# Datetime
# 2018-08-02 20:00:00  44057.0    20          3        3      8  2018
# 2018-08-02 21:00:00  43256.0    21          3        3      8  2018
# 2018-08-02 22:00:00  41552.0    22          3        3      8  2018
# 2018-08-02 23:00:00  38500.0    23          3        3      8  2018
# 2018-08-03 00:00:00  35486.0     0          4        3      8  2018
#
#                      dayofyear  dayofmonth  weekofyear     lag1     lag2  \
# Datetime
# 2018-08-02 20:00:00        214           2          31  42256.0  41485.0
# 2018-08-02 21:00:00        214           2          31  41210.0  40249.0
# 2018-08-02 22:00:00        214           2          31  39525.0  38698.0
# 2018-08-02 23:00:00        214           2          31  36490.0  35406.0
# 2018-08-03 00:00:00        215           3          31  33539.0  32094.0
#
#                         lag3
# Datetime
# 2018-08-02 20:00:00  38804.0
# 2018-08-02 21:00:00  38748.0
# 2018-08-02 22:00:00  37330.0
# 2018-08-02 23:00:00  34552.0
# 2018-08-03 00:00:00  31695.0

# %% [markdown]
# ### Train Using Cross Validation

# %%
tss = TimeSeriesSplit(n_splits=5, test_size=24*365*1, gap=24)
df = df.sort_index()


fold = 0
preds = []
scores = []
for train_idx, val_idx in tss.split(df):
    train = df.iloc[train_idx]
    test = df.iloc[val_idx]

    train = create_features(train)
    test = create_features(test)

    FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month','year',
                'lag1','lag2','lag3']
    TARGET = 'PJME_MW'

    X_train = train[FEATURES]
    y_train = train[TARGET]

    X_test = test[FEATURES]
    y_test = test[TARGET]

    reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                           n_estimators=1000,
                           early_stopping_rounds=50,
                           objective='reg:linear',
                           max_depth=3,
                           learning_rate=0.01)
    reg.fit(X_train, y_train,
            eval_set=[(X_train, y_train), (X_test, y_test)],
            verbose=100)

    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = np.sqrt(mean_squared_error(y_test, y_pred))
    scores.append(score)
# Out:
# [15:05:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [15:05:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:32732.52148	validation_1-rmse:31956.66211
# [100]	validation_0-rmse:12532.16113	validation_1-rmse:11907.12305
# [200]	validation_0-rmse:5744.94678	validation_1-rmse:5353.51660
# [300]	validation_0-rmse:3868.55591	validation_1-rmse:3898.53906
# [400]	validation_0-rmse:3430.63086	validation_1-rmse:3758.24512
# [500]	validation_0-rmse:3313.80835	validation_1-rmse:3774.01245
# [600]	validation_0-rmse:3257.79956	validation_1-rmse:3786.43457
# [700]	validation_0-rmse:3216.66553	validation_1-rmse:3794.42798
# [800]	validation_0-rmse:3181.24268	validation_1-rmse:3803.77270
# [900]	validation_0-rmse:3149.59058	validation_1-rmse:3796.79565
# [999]	validation_0-rmse:3120.67505	validation_1-rmse:3788.34766
# [15:06:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [15:06:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:32672.17188	validation_1-rmse:32138.89062
# [100]	validation_0-rmse:12513.58008	validation_1-rmse:12221.42090
# [200]	validation_0-rmse:5755.56055	validation_1-rmse:5655.33008
# [300]	validation_0-rmse:3904.97974	validation_1-rmse:3931.65942
# [400]	validation_0-rmse:3476.76343	validation_1-rmse:3598.75269
# [500]	validation_0-rmse:3355.49097	validation_1-rmse:3530.19678
# [600]	validation_0-rmse:3298.89185	validation_1-rmse:3492.70117
# [700]	validation_0-rmse:3258.68677	validation_1-rmse:3468.00293
# [800]	validation_0-rmse:3224.41553	validation_1-rmse:3446.84033
# [900]	validation_0-rmse:3196.68066	validation_1-rmse:3434.48120
# [999]	validation_0-rmse:3171.77686	validation_1-rmse:3422.73047
# [15:06:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [15:06:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:32631.18945	validation_1-rmse:31073.24219
# [100]	validation_0-rmse:12498.55762	validation_1-rmse:11133.99512
# [200]	validation_0-rmse:5748.85840	validation_1-rmse:4812.20947
# [300]	validation_0-rmse:3913.77100	validation_1-rmse:3546.83569
# [400]	validation_0-rmse:3491.37573	validation_1-rmse:3490.31372
# [500]	validation_0-rmse:3376.11011	validation_1-rmse:3547.43823
# [600]	validation_0-rmse:3318.25073	validation_1-rmse:3598.29492
# [700]	validation_0-rmse:3276.29150	validation_1-rmse:3624.87524
# [800]	validation_0-rmse:3244.78613	validation_1-rmse:3655.43115
# [900]	validation_0-rmse:3217.68945	validation_1-rmse:3683.82471
# [999]	validation_0-rmse:3190.67847	validation_1-rmse:3712.56494
# [15:07:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [15:07:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:32528.42578	validation_1-rmse:31475.38281
# [100]	validation_0-rmse:12461.93945	validation_1-rmse:12016.85742
# [200]	validation_0-rmse:5736.09619	validation_1-rmse:5797.82129
# [300]	validation_0-rmse:3912.41162	validation_1-rmse:4386.88525
# [400]	validation_0-rmse:3495.18506	validation_1-rmse:4173.48340
# [500]	validation_0-rmse:3380.56030	validation_1-rmse:4117.65527
# [600]	validation_0-rmse:3320.93896	validation_1-rmse:4108.32373
# [700]	validation_0-rmse:3280.72119	validation_1-rmse:4092.06616
# [800]	validation_0-rmse:3249.57739	validation_1-rmse:4095.15918
# [900]	validation_0-rmse:3220.31226	validation_1-rmse:4090.95776
# [999]	validation_0-rmse:3196.36670	validation_1-rmse:4065.66113
# [15:08:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [15:08:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:32462.06445	validation_1-rmse:31463.86719
# [100]	validation_0-rmse:12445.22168	validation_1-rmse:11954.79004
# [200]	validation_0-rmse:5750.43213	validation_1-rmse:5610.39258
# [300]	validation_0-rmse:3950.31274	validation_1-rmse:4149.66309
# [400]	validation_0-rmse:3539.13355	validation_1-rmse:4001.28784
# [500]	validation_0-rmse:3428.48096	validation_1-rmse:4028.80029
# [600]	validation_0-rmse:3372.04321	validation_1-rmse:4052.09351
# [700]	validation_0-rmse:3334.09814	validation_1-rmse:4052.86548
# [800]	validation_0-rmse:3304.11475	validation_1-rmse:4044.70776
# [900]	validation_0-rmse:3277.36475	validation_1-rmse:4037.74463
# [999]	validation_0-rmse:3251.40820	validation_1-rmse:4024.17700

# %%
print(f'Score across folds {np.mean(scores):0.4f}')
print(f'Fold scores:{scores}')
# Out:
# Score across folds 3802.6965
# Fold scores:[3788.3472265677688, 3422.7313522991994, 3712.565337136328, 4065.6619422063677, 4024.1768497078638]

# %% [markdown]
# ### Predicting the Future
# - Retraining on all data
# - To Predict the future we need an emtpy dataframe for future date ranges.
# - Run those dates through our feature creation code + lag creation

# %%
# Retrain on all data
df = create_features(df)

FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year',
            'lag1','lag2','lag3']
TARGET = 'PJME_MW'

X_all = df[FEATURES]
y_all = df[TARGET]

reg = xgb.XGBRegressor(base_score=0.5,
                       booster='gbtree',    
                       n_estimators=1000,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_all, y_all,
        eval_set=[(X_all, y_all)],
        verbose=100)
# Out:
# [19:27:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:32403.91602
# [100]	validation_0-rmse:12426.44824
# [200]	validation_0-rmse:5752.09961
# [300]	validation_0-rmse:3971.35303
# [400]	validation_0-rmse:3571.35107
# [500]	validation_0-rmse:3455.44165
# [600]	validation_0-rmse:3402.07812
# [700]	validation_0-rmse:3365.95801
# [800]	validation_0-rmse:3336.94067
# [900]	validation_0-rmse:3311.71582
# [999]	validation_0-rmse:3287.67798
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.01, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=4,
#              num_parallel_tree=1, objective='reg:linear', predictor='auto',
#              random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              subsample=1, tree_method='exact', validate_parameters=1,
#              verbosity=None)

# %%
df.index.max()
# Out:
# Timestamp('2018-08-03 00:00:00')

# %%
# Create future dataframe
future = pd.date_range('2018-08-03','2019-08-01', freq='1h')
future_df = pd.DataFrame(index=future)
future_df['isFuture'] = True
df['isFuture'] = False
df_and_future = pd.concat([df, future_df])
df_and_future = create_features(df_and_future)
df_and_future = add_lags(df_and_future)

# %%
future_w_features = df_and_future.query('isFuture').copy()

# %% [markdown]
# ### Predict the future

# %%
future_w_features['pred'] = reg.predict(future_w_features[FEATURES])

# %%
future_w_features['pred'].plot(figsize=(15, 5),
                               color=color_pal[4],
                               ms=1,
                               lw=1,
                               title='Future Predictions')
plt.show()

# %% [markdown]
# ### Saving Model For later

# %%
# Save model
reg.save_model('model.json')

# %%
reg_new = xgb.XGBRegressor()
reg_new.load_model('model.json')
future_w_features['pred'] = reg_new.predict(future_w_features[FEATURES])
future_w_features['pred'].plot(figsize=(15, 5),
                               color=color_pal[4],
                               ms=1, lw=1,
                               title='Future Predictions')
# Out:
# <AxesSubplot:title={'center':'Future Predictions'}>

# %% [markdown]
# ### Feature Creation

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

df = create_features(df)
df.head()

# %% [markdown]
# ### Visualize our Feature to Target Relationship

# %%
fig, ax = plt.subplots(figsize=(14, 8))
sns.boxplot(data=df, x='hour', y='PJME_MW')
ax.set_title('MW by Hour')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 8))
sns.boxplot(data=df, x='month', y='PJME_MW', palette='Blues')
ax.set_title('MW by Month')
plt.show()

# %% [markdown]
# ### Create our Model

# %%
train = create_features(train)
test = create_features(test)

FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year']
TARGET = 'PJME_MW'

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
# Fit the model
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       early_stopping_rounds=50,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)

reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)

# %% [markdown]
# ### Feature Importance

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year'],
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
# print(dir(reg))

# %%
# plt.bar(range(len(reg.feature_importances_)), reg.feature_importances_)
# plt.show()

# https://towardsdatascience.com/be-careful-when-interpreting-your-features-importance-in-xgboost-6e16132588e7
# https://machinelearningmastery.com/feature-importance-and-feature-selection-with-xgboost-in-python/
# https://mljar.com/blog/feature-importance-xgboost/

plt.xticks(rotation = 90)
plt.bar(['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year'], 
        reg.feature_importances_)
plt.show()

# %% [markdown]
# ### Forecast on Test

# %%
test['prediction'] = reg.predict(X_test)
df = df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = df[['PJME_MW']].plot(figsize=(15, 5))
df['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Dat and Prediction')
plt.show()

# %%
ax = df.loc[(df.index > '04-01-2018') & (df.index < '04-08-2018')]['PJME_MW'] \
    .plot(figsize=(15, 5), title='Week Of Data')
df.loc[(df.index > '04-01-2018') & (df.index < '04-08-2018')]['prediction'] \
    .plot() # .plot(style='.')
plt.legend(['Truth Data','Prediction'])
plt.show()

# %% [markdown]
# ### Score (RMSE)

# %%
score = np.sqrt(mean_squared_error(test['PJME_MW'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')

# %% [markdown]
# ### Calculate Error
# - Look at the worst and best predicted days

# %%
test['error'] = np.abs(test[TARGET] - test['prediction'])
test['date'] = test.index.date
test.groupby(['date'])['error'].mean().sort_values(ascending=False).head(10)
